# %%
import sys
import time as t
sys.path.append(r"C:\Users\vinay\OneDrive\Desktop\VATSA\VATSA")
from modules.visual.visual_pipeline import VATSA_VisualPipeline
from modules.visual.streaming import VATSA_VideoStream

pipeline = VATSA_VisualPipeline(
    encoder_path="vatsa_visual_encoder_cifar10_deeper_unfreeze.pth",
    device="cuda"
)

# Test with webcam (source=0) or video file (source="test.mp4")
stream = VATSA_VideoStream(pipeline, source=0, target_fps=15)
start_time = t.time()
benchmark = stream.run(show=True, save_path=f"vatsa_stream_output{int(start_time)}.mp4")
end_time = t.time()
print(f"Total processing time: {end_time - start_time:.2f} seconds")
print(benchmark)
# Out:
# Streaming started — press Q to quit
#
# 0: 480x640 1 person, 119.5ms
# Speed: 17.5ms preprocess, 119.5ms inference, 13.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13.8ms
# Speed: 2.5ms preprocess, 13.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 12.7ms
# Speed: 1.8ms preprocess, 12.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13.6ms
# Speed: 1.7ms preprocess, 13.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 14.3ms
# Speed: 1.3ms preprocess, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 13.3ms
# ...
