# %%
import sys
sys.path.insert(0, "C:/Edu/VATSA")

from modules.audio import VATSA_AudioPipeline

pipeline = VATSA_AudioPipeline(
    checkpoint_path="C:/Edu/VATSA/modules/audio/vatsa_audio_encoder_transfer.pth"
)

# Test on one ESC-50 file
test_file = "../../notebooks/data/audio/ESC-50/ESC-50-master/audio/1-110032-A-0.wav"
result    = pipeline.run(test_file)
print(f"Embedding shape: {result['embedding'].shape}")
print(f"Embedding norm:  {result['embedding'].norm():.4f}")
# Out:
# Loading weights: 100%|██████████| 211/211 [00:00<00:00, 30192.35it/s]
# [transformers] Wav2Vec2Model LOAD REPORT from: facebook/wav2vec2-base
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# quantizer.weight_proj.bias   | UNEXPECTED |  |
# quantizer.weight_proj.weight | UNEXPECTED |  |
# project_q.weight             | UNEXPECTED |  |
# project_q.bias               | UNEXPECTED |  |
# project_hid.weight           | UNEXPECTED |  |
# quantizer.codevectors        | UNEXPECTED |  |
# project_hid.bias             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# VATSA AudioPipeline ready — device: cuda
# C:\Edu/VATSA\modules\audio\pipeline.py:58: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(
# ...
